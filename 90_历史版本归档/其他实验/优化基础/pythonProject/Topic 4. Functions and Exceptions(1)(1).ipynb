# %% [markdown]
# # 1.1 Writing Function

# %% [markdown]
# Up to this point, We have been using the build-in functions from Python.
#
# Now, we will learn how to write function of our own. Common reasons to write your own functions:
#
# - To simply the code or to make it more readable when you have thousands line of codes.
# - When you need to use some procedure repeatively. With function written by yourself, you can just fix the function when there is a bug instead of look for errors everywhere you used this procedure.

# %% [markdown]
# # Here is how it works:

# %% [markdown]
# Declaring a function starts with a def keyword for 'define a function'. It then has a name, followed by brackets, (), which may contain function arguments and function keyword arguments. This is followed by a colon. The body of the function is then indented relative to the left-most text. Function arguments are defined in brackets following the name, with different inputs separated by commas. Any outputs are given with the return keyword, again with different variables separated by commas.
#
# *arguments* are the variables that functions *always* need, so `a` and `b` in `def add(a, b): return a + b`. The function won't work without them! Function arguments are sometimes referred to as *args*.
#
# *Keyword arguments* are the variables that are optional for functions, so `c` in `def add(a, b, c=5): return a + b - c`. If you do not provide a value for `c` when calling the function, it will automatically revert to `c=5`. Keyword arguments are sometimes referred to as *kwargs*.
# Let's see a very simple example of a function with a single argument (or arg):

# %%
# Always try to define all your functions at the top of your code file

def greet():
    print('Hello, my friend!')

# once the function is defined, you can invoke it as many times as you need

greet()
greet()
# Out:
# Hello, my friend!
# Hello, my friend!

# %% [markdown]
# ## Function with Parameter

# %%
# Example 1: write a function to get: the average of a sequence of numbers
input_numbers = [5.0, 3.5, 7.8, 9.9, 10.0]

# %%
# Step 1: write the code to compute the average 

sum = 0.0
for number in input_numbers:
    sum += number
average = sum / len(input_numbers)

# %%
# Step 1 - try it out

sum = 0.0
for number in input_numbers:
    sum += number
average = sum / len(input_numbers)


input_numbers = [5.0, 3.5, 7.8, 9.9, 10.0]
print(input_numbers)
print(average)
# Out:
# [5.0, 3.5, 7.8, 9.9, 10.0]
# 7.24

# %%
# Step 2: define the function
# input_number here is the parameter of the function;
    # parameter is a special type of variable, that only exists inside of a given function
    # we can have multiple parameters in a function, here we only have one
    # we never assign value to the parameter inside of the function when we define the function
    # we assign the value of the parameter when we call/invoke the function

def get_average(input_numbers):
    sum = 0.0
    for number in input_numbers:
        sum += number
    average = sum / len(input_numbers)
    print(average)

# %%
# Step 3: invoke/call the function
    # Here, the list [5.0, 3.5, 7.8, 9.9, 10.0] is called the argument.
    # we used this argument to assign values into the parameter 'input_numbers' in the get_average function
get_average([5.0, 3.5, 7.8, 9.9, 10.0])
# Out:
# 7.24

# %%
# must fill in the arguement when you invoke a function, otherwise it won't work
get_average()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # must fill in the arguement when you invoke a function, otherwise it won't work
# ----> 2 get_average()
#       4 60*100/90
#
# NameError: name 'get_average' is not defined

# %%
# must ensure to pass the correct type of argument for function to work, here is a wrong example
# by the way we define get_average, python expect a collectin of data like list or tuples
get_average(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # must ensure to pass the correct type of argument for function to work, here is a wrong example
#       2 # by the way we define get_average, python expect a collectin of data like list or tuples
# ----> 3 get_average(5)
#
# Cell In[8], line 10, in get_average(input_numbers)
#       8 def get_average(input_numbers):
#       9     sum = 0.0
# ---> 10     for number in input_numbers:
#      11         sum += number
#      12     average = sum / len(input_numbers)
#
# TypeError: 'int' object is not iterable

# %%
# this is to print the
get_average
# Out:
# <function __main__.get_average(input_numbers)>

# %%
# Example 2: function with 2 parameters
# the function is to get number of letters appears in a string

def print_letter_count(text, letter):
    counter = 0
    for char in text:
        if char == letter:
            counter += 1
    print('Number of', letter, 'is', counter)

# %%
# order of Position of the values of argument is important
print_letter_count('Welcome', 'e')
# Out:
# Number of e is 2

# %%
# wrong example: when order of the argument is switched
print_letter_count('e','Welcome')
# Out:
# Number of Welcome is 0

# %%
# python allows named arguemnt or keyword argument
    # text is the keyword/named argument,which is passed to a function using the parameter names as keywords.
    # welcome is the positional/value argument, which is the value we pass to the function
print_letter_count(text = 'Welcome', letter = 'e')
# Out:
# Number of e is 2

# %%
# with keyword argument, order does not matter
print_letter_count(letter = 'e', text = 'Welcome')
# Out:
# Number of e is 2

# %%
print_letter_count('People say nothing is impossible, but I do nothing everyday.', 'I')
# Out:
# Number of I is 1

# %% [markdown]
# ## Default Parameter Values

# %%
# reminder: 
    # end and sep here are 'named arguememts' or 'keyword' arguement'
    # they are optional and always have default value: end default is newline char and sep default value is space char
    
print('Hello', 'How are you?', end = '.', sep='-')
print(' ')
print('Hello', 'How are you?')
print('Hello', 'How are you?')
# Out:
# Hello-How are you?.

# %% [markdown]
# ### Let's see how keyword arguement works with function

# %%
# Example 1: function with two parameter and one of parameter has default value 

def print_letter_count(text, letter = 'a'):
    counter = 0
    for char in text:
        if char == letter:
            counter += 1
    print('Number of', letter, 'is', counter)
    
print_letter_count('How many letters a are here?')
# Out:
# Number of a is 3

# %%
print_letter_count('happy')
print_letter_count(text = 'happy')
print_letter_count(text = 'happy', letter = 'y')
# Out:
# Number of a is 3
# Number of a is 1
# Number of a is 1
# Number of y is 1

# %%
# Example 1 - wrong order of parameters

# Remark: parameter with default value must appear at the end 
    #in this case, paramter 'letter' comes before parameter 'text', we get error message

def print_letter_count(letter = 'a', text):
    counter = 0
    for char in text:
        if char == letter:
            counter += 1
    print('Number of', letter, 'is', counter)
# Out:
#   Cell In[37], line 6
#     def print_letter_count(letter = 'a', text):
#                                          ^
# SyntaxError: non-default argument follows default argument

# %%
# Again, empty argument is not recognized for function print_letter_count
print_letter_count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 # Again, empty argument is not recognized for function print_letter_count
# ----> 2 print_letter_count()
#
# TypeError: print_letter_count() missing 1 required positional argument: 'text'

# %%
# Example 2: function with two parameter and both of which have default value 

def print_letter_count(text = 'This is the default string to search', letter = 'a'):
    counter = 0
    for char in text:
        if char == letter:
            counter += 1
    print('Number of', letter, 'is', counter)
    
print_letter_count()
# Out:
# Number of a is 2

# %%
# try with a different positional argument
print_letter_count('search here', letter = 'a')
# Out:
# Number of a is 1

# %%
# all positional argument must come before named argument
    # 'search here' is the positional argument
    # 'letter=a' is the part with named argument
    # we get the order wrong in this case, so get error meesage
    
print_letter_count(letter = 'a', 'search here', )
# Out:
#   Cell In[41], line 6
#     print_letter_count(letter = 'a', 'search here', )
#                                                     ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ## 1.2 Name Scope

# %% [markdown]
# Two major Name Scope:
#
#     - local
#     - global

# %% [markdown]
# **Local**
#
# If you define a variable inside a function, the rest of your code won't be able to 'see' it or use it. For example, here's a function that creates a variable and then an example of calling that variable:
#
# ```python
# def var_func():
#     str_variable = 'Hello World!'
#
# var_func()
# print(str_variable)
# ```
#
# This would raise an error, because as far as your general code is concerned `str_variable` doesn't exist outside of the function. This is an example of a *local* variable, one that only exists within a function.
#
#
# If you want to create variables inside a function and have them persist, you need to explicitly pass them out using, for example `return str_variable` like this:

# %%
def var_func():
    str_variable = "Hello World!"
    return str_variable


returned_var = var_func()
print(returned_var)

# %% [markdown]
# **Global**
#
# A variable declared outside of a function is known as a global variable because it is accessible everywhere:

# %%
y = "I'm a global variable"

def print_y():
    print("y is inside a function:", y)


print_y()
print("y is outside a function:", y)
# Out:
# y is inside a function: I'm a global variable
# y is outside a function: I'm a global variable

# %% [markdown]
# ### Let's understand the local and global variable a bit better using example

# %%
# Example 1. a function that does not work
    # because mysterious_war is never defined
    
def show_truth():
    print(mysterious_var)
    
show_truth()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       4 def show_truth():
#       5     print(mysterious_var)
# ----> 7 show_truth()
#
# Cell In[6], line 5, in show_truth()
#       4 def show_truth():
# ----> 5     print(mysterious_var)
#
# NameError: name 'mysterious_var' is not defined

# %%
# Fix Example 1 - defining mysterious_var inside of the function
    
def show_truth():
    mysterious_var = 'Surprise!'
    print(mysterious_var)
    
show_truth()
# Out:
# Surprise!

# %%
# Fix Example 1 - defining mysterious_var after the function
    
def show_truth():
    print(mysterious_var)

mysterious_var = 'Surprise!'
show_truth()
# Out:
# Surprise!

# %%
# Fix Example 1 - redefining mysterious_var after the function
    
def show_truth():
    mysterious_var = 'New Surprise!'  # mysterious_var here is a local variable
    print(mysterious_var)

mysterious_var = 'Surprise!' # mysterious_var here is a global var
print(mysterious_var)
show_truth()  # when the funtion is invoked, the local var shadows the global var with the same name
print(mysterious_var)
# Out:
# Surprise!
# New Surprise!
# Surprise!

# %%
# Fix Example 1 - define a global var inside of the function
    # this global var inside of the function means:
        # don't use shadowing for the var called mysterious_var
        # or don't create second temporary var called mysterious_var, instead use this global var mysterious_var
        # 
    
def show_truth():
    global mysterious_var    # define a global var here 
    mysterious_var = 'New Surprise!'  # mysterious_var here is a local variable
    print(mysterious_var)

mysterious_var = 'Surprise!' # mysterious_var here is a global var
print(mysterious_var)
show_truth()  
print(mysterious_var) # having global mysterious_var insdie of the function changes the mysterious_var after the function is invoked.

# Remark: global var is rarely used, more than often, using global do more harm than good. So try to aviod it
# Out:
# Surprise!
# New Surprise!
# New Surprise!

# %%
# Example 2 - function and List

def show_truth():
    mysterious_var = ['New Surprise!']  # mysterious_var here is a local variable
    print(mysterious_var)

mysterious_var = ['Surprise!'] # mysterious_var here is a global var
print(mysterious_var)
show_truth()  
print(mysterious_var)
# Out:
# ['Surprise!']
# ['New Surprise!']
# ['Surprise!']

# %%
# Example 2 - function and List (continued)
    # we did not assign the new value of the list to the local var
    # instead, we append on the global variable
    # therefore, you will see 'print(mysterious_var)' prints the global var 
    
    # this applies to mutables like list and dictionaries, not tuples (immutable)

def show_truth():
    mysterious_var.append('New Surprise!')  # mysterious_var here is a local variable
    print(mysterious_var)

mysterious_var = ['Surprise!'] # mysterious_var here is a global var
print(mysterious_var)
show_truth()  
print(mysterious_var)  # after invoking the function, the global varible whish is a list, now is been updated.
# Out:
# ['Surprise!']
# ['Surprise!', 'New Surprise!']
# ['Surprise!', 'New Surprise!']

# %% [markdown]
# ## 1.3 Function returns: the None value and meaningful value

# %% [markdown]
# Function can typically:
#
#     - cause some effect (i.e show text in the console, create a file)
#     - return a meanigful value

# %% [markdown]
# ### The None Value

# %% [markdown]
# None is a special object that represents the absence of a value or the lack of a meaningful value. It is often used to indicate that a variable or expression does not have a valid or defined value.
#
# None is a built-in constant in Python, and it is typically used to initialize variables, function arguments, or return values when there is no specific value to assign or return.
#
# None is also used in conditional checks.

# %%
# this print function does nothing
print()

# %%
# this print function prints some string characters
print('hello')

# %%
# this length function returns a value
len('hello')
legnth=len('hello')

# %%
# this input function prompt for input and store the value entered
number = input('what is the number?')
print(number)

# %%
print_return = print('hello world') # print the 'hello world'
print(print_return)                 # assign the value of print in a var print_return

# Remark: None is a null value or no value, is a very special value. It is not 0, it is not false.
# Out:
# hello world
# None

# %% [markdown]
# ‘None‘ is a singleton object, meaning there is only one instance of it in a Python program. You can compare it using the 'is' operator to check if a variable contains None. For example:

# %%
x = None
if x is None:
    print('yes')
# Out:
# yes

# %% [markdown]
# But be cautious when comparing values to None. Always use the ‘is’ operator for comparison, as None is a singleton object. Using == to compare with None may not work as expected, so try to use 'is' instead of '==' for comparison with None.

# %%
x = None

if x is None:
    print('yes')
if x == None:
    print('it does')
# Out:
# yes
# it does

# %%
x = None

if x:    # means: if x is true
    print('None is True')
elif x is False:
    print('None is False')
else:
    print('None is not True, or False. None is just None')

# %% [markdown]
# When a function does not explicitly return a value, it implicitly returns None. For example:

# %%
def do_something():
    # This function does not have a return statement,
    # so it returns None by default.
    pass

result = do_something()
print(result)  # This will print "None"
# Out:
# None

# %%
def greet():
    print('hello!')

x = greet()
print(x)
# Out:
# hello!
# None

# %% [markdown]
# ‘None is often used to indicate the absence of a value in conditional statements or when testing the result of a function or expression. For example:

# %%
if some_value is None:
    print("The value is not defined.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 if some_value is None:
#       2     print("The value is not defined.")
#
# NameError: name 'some_value' is not defined

# %% [markdown]
# ### The return key

# %%
# In fact, it is not common to print the value inside of a function
    # instead, we return a value
    
def get_average(input_numbers):
    sum = 0.0
    for number in input_numbers:
        sum += number
    average = sum / len(input_numbers)
    return average 

# return is not a function, so don't have () come after it
# return does 2 things: return the result + exit the function

# %%
print('The average is:', get_average([5.0, 3.5, 7.8, 9.9, 10.0]))
# Out:
# The average is: 7.24

# %%
average = get_average([5.0, 3.5, 7.8, 9.9,10.0])
if average > 5.0:
    print('The average is too high')
# Out:
# The average is too high

# %%
# Example: print() after return is ignored, because python has exit the function after return

def get_average(input_numbers):
    sum = 0.0
    for number in input_numbers:
        sum += number
    average = sum/len(input_numbers)
    return average
    print('Show me!')

# try out the function, you will see print() is ignored.
get_average([12])
# Out:
# 12.0

# %%
def is_first_last_equal(number_list):
    if (number_list[0] == number_list[-1]):
        return True
    else:
        return False

# %%
print(is_first_last_equal([10,20,30,40,10]))
# Out:
# True

# %%
print(is_first_last_equal([10,20,30,40,50]))
# Out:
# False

# %%
print(is_first_last_equal([]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 print(is_first_last_equal([]))
#
# Cell In[31], line 2, in is_first_last_equal(number_list)
#       1 def is_first_last_equal(number_list):
# ----> 2     if (number_list[0] == number_list[-1]):
#       3         return True
#       4     else:
#
# IndexError: list index out of range

# %%
def is_first_last_equal(number_list):
    if len(number_list) == 0:
        return
    if (number_list[0] == number_list[-1]):
        return True
    else:
        return False

# %%
print(is_first_last_equal([10,20,30,40,10]))
# Out:
# True

# %%
print(is_first_last_equal([10,20,30,40,50]))
# Out:
# False

# %%
print(is_first_last_equal([]))
# Out:
# None

# %% [markdown]
# <blockquote class="Exercise"><p lang="en" dir="ltr">In Class Exercise:
#
#     Get Rid of Duplicates!
# Write a function named unique. The function should accept one parameter, which is a list with any number of elements inside. The default value for the parameter should be an empty list ([]).
#
# The function should return a new list with all duplicate elements removed. The function should preserve the original order of elements.
#
# Example 1: for unique([1, 1, 4, 5, 1]), the output should be [1, 4, 5]
# Example 2: for unique(['Mark', 'Mark', 'John', 'Anne']), the output should be  ['Mark', 'John', 'Anne']
#
# </blockquote>

# %% [markdown]
# ## 1.4 Recursion

# %%
# Let's say we want to write function does factorial
# 3! = 1 + 2 + 3 =6
# 5% = 1 * 2 * 3 * 4 * 5 = 120

# %%
# Example: a function without recursion
def get_factorial(number):
    factorial = 1
    for x in range(1, number +1):
        factorial *= x
    return factorial

# %%
print(get_factorial(6))
# Out:
# 720

# %%
1! = 1
2! = 2 * 1             = 2 * 1!
3! = 3 * 2 * 1         = 3 * 2!
4! = 4 * 3* 2 * 1      = 4 * 3!
5! = 5 * 4 * 3 * 2 *1  = 5 * 4!

# %%
def get_factorial_recursive(number):
    return number * get_factorial_recursive(number-1)

# this function is not working & let's have a try

# %%
get_factorial_recursive(6)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 get_factorial_recursive(6)
#
# Cell In[43], line 2, in get_factorial_recursive(number)
#       1 def get_factorial_recursive(number):
# ----> 2     return number * get_factorial_recursive(number-1)
#
# Cell In[43], line 2, in get_factorial_recursive(number)
#       1 def get_factorial_recursive(number):
# ----> 2     return number * get_factorial_recursive(number-1)
#
#     [... skipping similar frames: get_factorial_recursive at line 2 (2971 times)]
#
# Cell In[43], line 2, in get_factorial_recursive(number)
#       1 def get_factorial_recursive(number):
# ----> 2     return number * get_factorial_recursive(number-1)
#
# RecursionError: maximum recursion depth exceeded

# %%
# need to add stop condition, so the function will stop at some value of number
 # otherwise, this program will just go from 1 to 0, to -1 and ... to - infinity
    
# we know that in fact we can only do factorials to zero as the smallest


def get_factorial_recursive(number):
    if number < 1:
        return 1
    return number * get_factorial_recursive(number-1)

# %%
# = 6* 5!

get_factorial_recursive(6)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[45], line 3
#       1 # = 6* 5!
# ----> 3 get_factorial_recursive(6)
#
# Cell In[43], line 2, in get_factorial_recursive(number)
#       1 def get_factorial_recursive(number):
# ----> 2     return number * get_factorial_recursive(number-1)
#
# Cell In[43], line 2, in get_factorial_recursive(number)
#       1 def get_factorial_recursive(number):
# ----> 2     return number * get_factorial_recursive(number-1)
#
#     [... skipping similar frames: get_factorial_recursive at line 2 (2971 times)]
#
# Cell In[43], line 2, in get_factorial_recursive(number)
#       1 def get_factorial_recursive(number):
# ----> 2     return number * get_factorial_recursive(number-1)
#
# RecursionError: maximum recursion depth exceeded

# %%
get_factorial_recursive(-1)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 get_factorial_recursive(-1)
#
# Cell In[43], line 2, in get_factorial_recursive(number)
#       1 def get_factorial_recursive(number):
# ----> 2     return number * get_factorial_recursive(number-1)
#
# Cell In[43], line 2, in get_factorial_recursive(number)
#       1 def get_factorial_recursive(number):
# ----> 2     return number * get_factorial_recursive(number-1)
#
#     [... skipping similar frames: get_factorial_recursive at line 2 (2971 times)]
#
# Cell In[43], line 2, in get_factorial_recursive(number)
#       1 def get_factorial_recursive(number):
# ----> 2     return number * get_factorial_recursive(number-1)
#
# RecursionError: maximum recursion depth exceeded

# %%
get_factorial_recursive(0)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 get_factorial_recursive(0)
#
# Cell In[43], line 2, in get_factorial_recursive(number)
#       1 def get_factorial_recursive(number):
# ----> 2     return number * get_factorial_recursive(number-1)
#
# Cell In[43], line 2, in get_factorial_recursive(number)
#       1 def get_factorial_recursive(number):
# ----> 2     return number * get_factorial_recursive(number-1)
#
#     [... skipping similar frames: get_factorial_recursive at line 2 (2971 times)]
#
# Cell In[43], line 2, in get_factorial_recursive(number)
#       1 def get_factorial_recursive(number):
# ----> 2     return number * get_factorial_recursive(number-1)
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ## Generators

# %%
def get_number():
    for i in range(1,4):
        return i 
    
get_number()
# Out:
# 2

# %%
# when you want to return  a set of numbers one by one

def get_number():
    for i in range(1,4):
        yield i 

# using yield instead of return, the fuction become a generator

# %%
print(get_number)
# Out:
# <function get_number at 0x10562a3e0>

# %%
# need to store the generator in a number

generator = get_number()
print(next(generator)) # the next function will get a different generator each time you run generator again
print(next(generator))
print(next(generator))
print(next(generator))
# Out:
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[57], line 7
#       5 print(next(generator))
#       6 print(next(generator))
# ----> 7 print(next(generator))
#
# StopIteration:

# %%
# Ways to avoid running into the value that is out of range 

# meothod 1: use for loop 
for x in get_number():
    print(x)
# Out:
# 1
# 2
# 3

# %%
# meothod 2: convert it to a list

number = list(get_number())
print(number)
# Out:
# [1, 2, 3]

# %% [markdown]
# ## Exceptions

# %% [markdown]
# An *exception* is an event which occurs during the execution of a program that disrupts the normal flow of the program insutrctions

# %% [markdown]
# Here are some examples of built-in exception in Python:
#
#     - IndentationError
#     - TypeError
#     - ValueError
#     - ZeroDivisionError

# %%
# most of the common errors are syntax error

# IndentationError
if True:
print('hello')
# Out:
#   Cell In[60], line 3
#     print('hello')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
# value error
value = int(input('Enter an intrger: '))
print('The inverse of', value, 'is', 1/value)
# value error when provide 0 and a
# Out:
# Enter an intrger: ok
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 2
#       1 # value error
# ----> 2 value = int(input('Enter an intrger: '))
#       3 print('The inverse of', value, 'is', 1/value)
#
# ValueError: invalid literal for int() with base 10: 'ok'

# %%
# how to handle exceptions?

try:       # use keyword try
    value = int(input('Enter an intrger: '))
    print('The inverse of', value, 'is', 1/value)
except:     # use keyword except to handle except
    print('You did not provide a number, so I will not calculate the inverse')

# except here will not stop the programming execution

# input 'a' and '0' will result in the print the results in except, but it is not a error

# %%
# Alternatively, we can specify two except seprately
    # each type of error (value error or zero error) can't be sepcified more than once

try:     
    value = int(input('Enter an intrger: '))
    print('The inverse of', value, 'is', 1/value)
except ValueError:    
    print('You did not provide a number, so I will not calculate the inverse')
except ZeroDivisionError:
    print('You did not provide 0 and division by zero is not possible, sorry')

# %%
# What a other excepts? Add one more except for all rest types of possible errors.

try:     
    value = int(input('Enter an intrger: '))
    print('The inverse of', value, 'is', 1/value)
except ValueError:    
    print('You did not provide a number, so I will not calculate the inverse')
except ZeroDivisionError:
    print('You did not provide 0 and division by zero is not possible, sorry')
except:
    print('Something strange happened, sorry?')

# %%
# To Sum-Up

try:
  # your code
except:
  # any exception

# %% [markdown]
# These exceptions are usually generated automatically by Python when it encounters a such error while parsing your code. You can, however, raise other types of exceptions programmatically when handling exceptional conditions in your code.
#
# Please note that it's uncommon to manually raise SyntaxError exceptions in your code.

# %%
# A special case: Syntax Error 
    #if you raise it manually, you can catch it in except block

try:
  raise SyntaxError
except:
  print('Got it!') # SyntaxError is caught here
# Out:
# Got it!

# %%
try:
    raise SyntaxError("This is a custom syntax error message")
except SyntaxError as e:
    print("Caught a SyntaxError:", e)
# Out:
# Caught a SyntaxError: This is a custom syntax error message

# %%
# A special case: Syntax Error 
    #if you make syntax error in try block, then python automatically raise a Syntax Error and you cannot catch it.
    
try:
  5:4 # this line generates a SyntaxError
except:
  print('Got it!') # SyntaxError is NOT caught here
# Out:
#   Cell In[63], line 5
#     5:4 # this line generates a SyntaxError
#     ^
# SyntaxError: illegal target for annotation

# %% [markdown]
# ## Exception Hierarchy (For beginner)

# %% [markdown]
# ![Exception%20Hierarchy.png](attachment:Exception%20Hierarchy.png)

# %%
# Top level: BaseException is used internally in Python, you normally don't see it

# Second level: 
    # SystemExit, it is a method allows you to close your program manually.
    # KeyboardInterrupt
    # Exception: ValueError and ZeroDivisionError we have covered all fall under this hierarchy
        # LooUpError include IndexError and KeyError, we will see them when working with List and Disctionaries
        
        

# Python always display most specific error type, namely the lowest error type in the hierarchy

# %%
# Example of SystemExit

# import special sys module from python
import sys

user_name = input('What is your name?')
if user_name == '':
    print('Empty name? I can\'t deal with that. I am closing the program. Bye')
    sys.exit()
print('Hello,', user_name)
print('let us get started...')
# Out:
# What is your name?
# Empty name? I can't deal with that. I am closing the program. Bye
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# Cell In[67], line 9
#       7 if user_name == '':
#       8     print('Empty name? I can\'t deal with that. I am closing the program. Bye')
# ----> 9     sys.exit()
#      10 print('Hello,', user_name)
#      11 print('let us get started...')
#
# SystemExit:

# %%
# Example of KeyboardInterrupt:
    # It is like we press stop in the kernel when the program runs into a infinite loop.
    
# while True:
#     print('Hi!')

# %%
# Example of IndexError

programming_languages = ['Java', 'Python', 'C++']
print(programming_languages[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Example of Exception
#       3 programming_languages = ['Java', 'Python', 'C++']
# ----> 4 print(programming_languages[10])
#
# IndexError: list index out of range

# %%
# Example of KeyError

ages = {'Mike': 20, "Brian":39, "Kevin": 59}
print(ages['Tim'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 4
#       1 # Example of KeyError
#       3 ages = {'Mike': 20, "Brian":39, "Kevin": 59}
# ----> 4 print(ages['Tim'])
#
# KeyError: 'Tim'

# %%
# Example of TypeError
    # age here is a string, so can't be used to add 10, so TypeError
    
ages = input('What is your age')
print('In 10 years you will be', ages+10, 'old')
# Out:
# What is your age10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 # Example of TypeError
#       3 ages = input('What is your age')
# ----> 4 print('In 10 years you will be', ages+10, 'old')
#
# TypeError: can only concatenate str (not "int") to str

# %%
# here the type of the content in input is correct,because a is a string
# but the content of int should be a number, so ValueError
age = int(input('What is your age?'))
# Out:
# What is your age?a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 age = int(input('What is your age?'))
#
# ValueError: invalid literal for int() with base 10: 'a'

# %% [markdown]
# ## Exception - Propagation

# %% [markdown]
# When you have several functions calling each other, and you may enter into Errors. Propagation is delegating the exception for the functions above to handle the potential errors.

# %%
def get_day(user_info):
    day = int(input('What is the day of your birthday? '))
    user_info.append(day)

def get_month(user_info):
    month = int(input('What is the month(1-12) of your birthday? '))
    user_info.append(month)
    
def get_year(user_info):
    year = int(input('What is the year of your birthday? '))
    user_info.append(year)

def get_user_bday(user_info):
    get_day(user_info)
    get_month(user_info)
    get_year(user_info)
    print('So your bday is',user_info)
    
print('Hi, I will collect some infor about your bday!')
user_info = []
get_user_bday(user_info)
# Out:
# Hi, I will collect some infor about your bday!
# What is the day of your birthday? 8
# What is the month(1-12) of your birthday? 12
# What is the year of your birthday? 1993
# So your bday is [8, 12, 1993]

# %%
def get_day(user_info):
    day = int(input('What is the day of your birthday? '))
    user_info.append(day)

def get_month(user_info):
    month = int(input('What is the month(1-12) of your birthday? '))
    user_info.append(month)
    
def get_year(user_info):
    year = int(input('What is the year of your birthday? '))
    user_info.append(year)

def get_user_bday(user_info):
        get_day(user_info)
        get_month(user_info)
        get_year(user_info)
        print('So your bday is',user_info)

print('Hi, I will collect some infor about your bday!')
user_info = []
get_user_bday(user_info)
# Out:
# Hi, I will collect some infor about your bday!
# What is the day of your birthday? 8
# What is the month(1-12) of your birthday? a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 21
#      19 print('Hi, I will collect some infor about your bday!')
#      20 user_info = []
# ---> 21 get_user_bday(user_info)
#
# Cell In[10], line 15, in get_user_bday(user_info)
#      13 def get_user_bday(user_info):
#      14     get_day(user_info)
# ---> 15     get_month(user_info)
#      16     get_year(user_info)
#      17     print('So your bday is',user_info)
#
# Cell In[10], line 6, in get_month(user_info)
#       5 def get_month(user_info):
# ----> 6     month = int(input('What is the month(1-12) of your birthday? '))
#       7     user_info.append(month)
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
# Let's fix it using try and except with ValueError

def get_day(user_info):
    day = int(input('What is the day of your birthday? '))
    user_info.append(day)

def get_month(user_info):
    month = int(input('What is the month(1-12) of your birthday? '))
    user_info.append(month)
    
def get_year(user_info):
    year = int(input('What is the year of your birthday? '))
    user_info.append(year)

def get_user_bday(user_info):
    try:
        get_day(user_info)
        get_month(user_info)
        get_year(user_info)
        print('So your bday is',user_info)
    except ValueError:
        print('You entered incorrect data,bye!')
print('Hi, I will collect some infor about your bday!')
user_info = []
get_user_bday(user_info)
# Out:
# Hi, I will collect some infor about your bday!
# What is the day of your birthday? 19
# What is the month(1-12) of your birthday? a
# You entered incorrect data,bye!

# %%
# Let's do an example of ZeroDivisionError

def my_fun(x):
        return x / x

my_fun(1)
my_fun(2)
# Out:
# 1.0

# %%
my_fun(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 my_fun(0)
#
# Cell In[3], line 4, in my_fun(x)
#       3 def my_fun(x):
# ----> 4         return x / x
#
# ZeroDivisionError: division by zero

# %%
# run into ZeroDivisionError when x = 0, because no number can be divided by 0
    # let's fix it with try-except block
        # try_except block tells python to catch the Error when it sees it (instead of generating warning message) and do something
        
def my_fun(x):
    try:
        return x / x
    except:
        print('ex')

my_fun(0)
my_fun(1)
# Out:
# ex
# 1.0

# %%
my_fun(0)
my_fun(2)
my_fun(1)
# Out:
# ex
# 1.0

# %%
my_fun(2)
my_fun(0)
my_fun(1)
# Out:
# ex
# 1.0

# %%
# if you want python to not producing any result for the except, then can try following code:
def my_fun(x):
    try:
        result = x / x
    except:
        return None
    return result

my_fun(0)
my_fun(2)
my_fun(0)

# %% [markdown]
# ## Assertion

# %% [markdown]
# Assertion is used when we want to raise the exceptions by oursevles.
# - Typically, it is used to debugging/testing the code or documenting your code.
# -  Don't use assertion to validate your user input
# -  It is not an error handling tool, but used to notify you the bugs

# %% [markdown]
# Assertions is something in our program that we believe is always true. Or, it is something should always true so our function can work properly.

# %%
# if assertion is not true, python return a message we defined in line 2

def calcualte_inverse(number):
    assert(number != 0), 'Got 0 as a number!'
    return 1/number

# %%
calcualte_inverse(0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 calcualte_inverse(0)
#
# Cell In[70], line 4, in calcualte_inverse(number)
#       3 def calcualte_inverse(number):
# ----> 4     assert(number != 0), 'Got 0 as a number!'
#       5     return 1/number
#
# AssertionError: Got 0 as a number!

# %%
for i in range(2):
    print("#")
print("#")
# Out:
# #
# #
# #

# %%
def func(a):
    a+=2
    return a
a=5
a=func(a)
print(a)
# Out:
# 7

# %%
def my_dream(A):
    a=a+1
    return a
a=5
print(a)
print(my_dream(a))
print(a)
# Out:
# 5
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[17], line 6
#       4 a=5
#       5 print(a)
# ----> 6 print(my_dream(a))
#       7 print(a)
#
# Cell In[17], line 2, in my_dream(A)
#       1 def my_dream(A):
# ----> 2     a=a+1
#       3     return a
#
# UnboundLocalError: cannot access local variable 'a' where it is not associated with a value

# %%
a=0
while a<8:
    a+=2
    if a%2==0:
        continue
    print("#")
