# %%
def cal(ori_str=[]):
    new_str=""
    for el in ori_str[0]:
        if el not in ["e","i","o","u"]:
            new_str+=el
    return new_str
new_str=cal(["Hello,world!"])
print(new_str)
# Out:
# Hll,wrld!

# %%
def cal(ori_str=""):
    new_str = ""
    for el in ori_str:
        if el not in ["e", "i", "o", "u"]:
            new_str+=el
    return new_str
new_str = cal("Hello,world!")
print(new_str)
# Out:
# Hll,wrld!
